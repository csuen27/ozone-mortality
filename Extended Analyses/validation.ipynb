# %%
import warnings
warnings.filterwarnings("ignore")

import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import ExtraTreesRegressor
from xgboost import XGBRegressor 
from sklearn.linear_model import LinearRegression as LinearR 
from sklearn.metrics import mean_squared_error as MSE 
from sklearn.metrics import r2_score as R2

# %%
data = pd.read_csv('/Volumes/Database/Backups/202110bkp/COVID/Analysis/1.1 obs/TOAR/toar_obs_2015-2021.csv')

# %%
data
# Out:
#         site       date  year  month   latitude  longitude      da24h  \
# 0      16601   2015/1/1  2015      1  54.924970   8.308210  30.043789
# 1      16601   2015/2/1  2015      2  54.924970   8.308210  29.450625
# 2      16601   2015/3/1  2015      3  54.924970   8.308210  34.476417
# 3      16601   2015/4/1  2015      4  54.924970   8.308210  40.462480
# 4      16601   2015/5/1  2015      5  54.924970   8.308210  41.979728
# ...      ...        ...   ...    ...        ...        ...        ...
# 29556  48342   2021/6/1  2021      6  49.191996   7.614573  31.590637
# 29557  48342   2021/7/1  2021      7  49.191996   7.614573  25.456019
# 29558  48342   2021/8/1  2021      8  49.191996   7.614573  21.924475
# 29559  48342   2021/9/1  2021      9  49.191996   7.614573  24.066513
# 29560  48342  2021/10/1  2021     10  49.191996   7.614573  22.122254
#
#            mda8h  lon_2  lat_2
# 0      43.422414      9     55
# 1      42.624729      9     55
# ...

# %%
data_2 = data.groupby(['year','month','lon_2','lat_2']).mean()[['mda8h']]
data_2
# Out:
#                             mda8h
# year month lon_2 lat_2
# 2015 1     -171  -15          NaN
#            -157   71    40.831250
#            -149   63    42.875000
#                   69    47.788337
#            -125   41    29.088125
# ...                           ...
# 2021 10     13    51          NaN
#                   53          NaN
#                   55          NaN
#             15    51          NaN
#                   53          NaN
#
# [9597 rows x 1 columns]

# %%
data_2.to_csv('/Volumes/Database/Backups/202110bkp/COVID/Analysis/1.1 obs/TOAR/toar_obs_2015-2021_2*2.csv')
