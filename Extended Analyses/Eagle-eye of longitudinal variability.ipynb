# %% [markdown]
# ### This Notebook is to demonstrate a closer look at the longitudinal trends of population-weighted O$_3$ exposure levels during 2005–2019, in comparison with literature where there are satellite-based remote-sensing measurements.

# %%
import warnings
warnings.filterwarnings("ignore")

import pandas as pd
import numpy as np

from sklearn.linear_model import LinearRegression as LinearR 
from sklearn.metrics import mean_squared_error as MSE 
from sklearn.metrics import r2_score as R2
from scipy.stats import gaussian_kde

from matplotlib import rcParams
import matplotlib.pyplot as plt

# %% [markdown]
# #### The well-developed and processed O$_3$ trend dataset is saved on 26 September, 2022, thus labelling the file with suffix "(0926)".

# %%
conc = pd.read_csv('/Volumes/Database/CHNoz/conc/ozone_trend_by_region(0926).csv')

f = plt.figure(num=None, figsize=(8, 5.75), dpi=300, facecolor='w', edgecolor='k')
plt.rcParams['font.sans-serif']=['Arial']

data = conc[conc['region'] == "全国"] ## The label in Chinese "全国" means "nationwide"
X=data['year']; y1=data['urban']; y2=data['popwt']; y3=data['rural']
plt.bar(X, y3-y2, width=0.75, color='red',      alpha=0.35, bottom=y2); 
plt.bar(X, y2-y1, width=0.75, color='darkgrey', alpha=0.35, bottom=y1)
plt.plot(X, y2, color='black', marker='o', markerfacecolor='white')
plt.xlim(2004,2020); plt.ylim(50,70)
plt.xticks([2005, 2010, 2015, 2019], fontsize=10); plt.yticks(np.arange(50, 71, step=5), fontsize=10)
plt.xlabel("Year", fontsize=12)
plt.ylabel("Average OSMDA8 ozone exposure (ppb)", fontsize=12)
# Out:
# Text(0, 0.5, 'Average OSMDA8 ozone exposure (ppb)')
